# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
import seaborn as sns

data = pd.read_csv("attention-study.csv")
data = data.drop(columns="Unnamed: 0")

data["att_cat"] = data['attention'].apply(lambda x: str(x) + ' ')

sns.displot(
    data, 
    x="ror_volatility", 
    hue="attention", 
    element='step'
)

# %%
data
# Out:
#      ('aLvl_mean', 'CRRA: 3.33, DiscFac: 0.95')  \
# 0                                      0.945635
# 1                                      0.947090
# 2                                      1.014663
# 3                                      1.000917
# 4                                      1.134656
# ..                                          ...
# 443                                    1.223659
# 444                                    0.976833
# 445                                    0.363181
# 446                                    0.462404
# 447                                    0.882725
#
#      ('aLvl_mean', 'CRRA: 3.33, DiscFac: 0.97')  \
# 0                                      0.956837
# 1                                      0.982718
# 2                                      1.083417
# 3                                      0.872444
# 4                                      1.171000
# ..                                          ...
# ...

# %%
means = data.columns[:6]
stds = data.columns[6:12]

# %%
data[list(means) + ['attention']]
# Out:
#      ('aLvl_mean', 'CRRA: 3.33, DiscFac: 0.95')  \
# 0                                      0.945635
# 1                                      0.947090
# 2                                      1.014663
# 3                                      1.000917
# 4                                      1.134656
# ..                                          ...
# 443                                    1.223659
# 444                                    0.976833
# 445                                    0.363181
# 446                                    0.462404
# 447                                    0.882725
#
#      ('aLvl_mean', 'CRRA: 3.33, DiscFac: 0.97')  \
# 0                                      0.956837
# 1                                      0.982718
# 2                                      1.083417
# 3                                      0.872444
# 4                                      1.171000
# ..                                          ...
# ...

# %%
mdata_mean = pd.melt(
    data[list(means) + ['attention']], 
    id_vars=['attention'], 
    value_vars=list(data.columns[:6]),
    var_name="stat"
)

mdata_std = pd.melt(
    data[list(stds) + ['attention']], 
    id_vars=['attention'], 
    value_vars=list(data.columns[6:12]),
    var_name="stat"
)

# %%
fig, ax = plt.subplots(figsize=(10,8))
sns.lineplot(
    ax=ax,
    data=mdata_mean,
    x="attention",
    y="value",
    hue="stat")
# Out:
# <AxesSubplot:xlabel='attention', ylabel='value'>

# %%
fig, ax = plt.subplots(figsize=(10,8))
sns.lineplot(
    ax=ax,
    data=mdata_std,
    x="attention",
    y="value",
    hue="stat")
# Out:
# <AxesSubplot:xlabel='attention', ylabel='value'>

# %%
fig, ax = plt.subplots(figsize=(10,8))
sns.lineplot(
    ax=ax,
    data=data,
    x="attention",
    y="ror_volatility")
# Out:
# <AxesSubplot:xlabel='attention', ylabel='ror_volatility'>

# %%
ddata = pd.read_csv("dividend-study.csv")
ddata = ddata.drop(columns="Unnamed: 0")

# %%
ddata['dstats'] = ddata['dividend_ror'].apply(lambda x : 'ror:' + str(x)) + ddata['dividend_std'].apply(lambda x : 'std:' + str(x))

# %%
sns.lineplot(
    data = ddata,
    x = 'dividend_ror',
    y = 'ror_volatility',
    hue = 'dividend_std'
)
# Out:
# <AxesSubplot:xlabel='dividend_ror', ylabel='ror_volatility'>

# %%
sns.lineplot(
    data = ddata,
    x = 'dividend_std',
    y = 'ror_volatility',
    hue = 'dividend_ror'
)
# Out:
# <AxesSubplot:xlabel='dividend_std', ylabel='ror_volatility'>

# %%
ddata
# Out:
#      ('aLvl_mean', 'CRRA: 3.33, DiscFac: 0.95')  \
# 0                                      0.871536
# 1                                      0.527623
# 2                                      0.981274
# 3                                      0.467789
# 4                                      0.582344
# ..                                          ...
# 283                                    1.117150
# 284                                    2.088700
# 285                                    0.748988
# 286                                    0.779437
# 287                                    1.329548
#
#      ('aLvl_mean', 'CRRA: 3.33, DiscFac: 0.97')  \
# 0                                      0.861907
# 1                                      0.597707
# 2                                      1.237310
# 3                                      0.450031
# 4                                      0.514418
# ..                                          ...
# ...
