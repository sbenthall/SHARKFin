# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
import seaborn as sns

rdata = pd.read_csv("study-2021-Jun-14_21:25.csv")
rdata = rdata.drop(columns="Unnamed: 0")

rdata["att_cat"] = data['attention'].apply(lambda x: str(x) + ' ')
rdata["mock"] = data['seconds'] < 100

data = rdata[~data["mock"]]
 
sns.displot(
    data[~data['mock']], 
    x="ror_volatility", 
    hue="attention", 
    element='step'
)

# %%
data
# Out:
#      ('aLvl_mean', 'CRRA: 3.33, DiscFac: 0.95')  \
# 0                                      0.377804
# 1                                      0.391418
# 2                                      0.156926
# 3                                      0.818857
# 4                                      0.251842
# ..                                          ...
# 165                                    0.306612
# 166                                    0.132826
# 167                                    0.204685
# 168                                    0.277392
# 169                                    0.793585
#
#      ('aLvl_mean', 'CRRA: 3.33, DiscFac: 0.97')  \
# 0                                      0.383700
# 1                                      0.419578
# 2                                      0.165370
# 3                                      0.369475
# 4                                      0.265152
# ..                                          ...
# 165                                    0.322638
# 166                                    0.132908
# 167                                    0.210390
# 168                                    0.298045
# 169                                    0.865397
#
#      ('aLvl_mean', 'CRRA: 6.0, DiscFac: 0.95')  \
# 0                                     0.849022
# 1                                     1.656456
# 2                                     0.974072
# 3                                     0.915677
# 4                                     0.756402
# ..                                         ...
# 165                                   0.701210
# 166                                   0.429886
# 167                                   0.558424
# 168                                   0.638733
# 169                                   1.478322
#
#      ('aLvl_mean', 'CRRA: 6.0, DiscFac: 0.97')  \
# 0                                     0.901912
# 1                                     1.181922
# 2                                     0.553890
# 3                                     0.943139
# 4                                     0.733352
# ..                                         ...
# 165                                   0.761912
# 166                                   0.464077
# 167                                   0.559453
# 168                                   0.633166
# 169                                   1.484355
#
#      ('aLvl_mean', 'CRRA: 8.67, DiscFac: 0.95')  \
# 0                                      1.166165
# 1                                      1.859732
# 2                                      0.758705
# 3                                      1.201748
# 4                                      1.034339
# ..                                          ...
# 165                                    1.037009
# 166                                    0.613283
# 167                                    0.772055
# 168                                    0.856155
# 169                                    1.934880
#
#      ('aLvl_mean', 'CRRA: 8.67, DiscFac: 0.97')  \
# 0                                      1.159661
# 1                                      1.570719
# 2                                      0.750023
# 3                                      1.149143
# 4                                      1.026293
# ..                                          ...
# 165                                    1.068629
# 166                                    0.599957
# 167                                    0.779638
# 168                                    0.877339
# 169                                    3.343068
#
#      ('aLvl_std', 'CRRA: 3.33, DiscFac: 0.95')  \
# 0                                     0.040886
# 1                                     0.015979
# 2                                     0.008840
# 3                                     1.116104
# 4                                     0.000899
# ..                                         ...
# 165                                   0.050427
# 166                                   0.026487
# 167                                   0.014272
# 168                                   0.013994
# 169                                   0.120247
#
#      ('aLvl_std', 'CRRA: 3.33, DiscFac: 0.97')  \
# 0                                     0.016500
# 1                                     0.035096
# 2                                     0.012417
# 3                                     0.034826
# 4                                     0.003236
# ..                                         ...
# 165                                   0.028251
# 166                                   0.015341
# 167                                   0.007376
# 168                                   0.009071
# 169                                   0.073779
#
#      ('aLvl_std', 'CRRA: 6.0, DiscFac: 0.95')  \
# 0                                    0.029763
# 1                                    1.072083
# 2                                    1.038600
# 3                                    0.051191
# 4                                    0.037542
# ..                                        ...
# 165                                  0.015806
# 166                                  0.063858
# 167                                  0.002598
# 168                                  0.012003
# 169                                  0.093423
#
#      ('aLvl_std', 'CRRA: 6.0, DiscFac: 0.97')  \
# 0                                    0.048448
# 1                                    0.126739
# 2                                    0.039914
# 3                                    0.075061
# 4                                    0.036554
# ..                                        ...
# 165                                  0.022606
# 166                                  0.094828
# 167                                  0.004200
# 168                                  0.005585
# 169                                  0.127054
#
#      ('aLvl_std', 'CRRA: 8.67, DiscFac: 0.95')  \
# 0                                     0.052834
# 1                                     0.748476
# 2                                     0.048292
# 3                                     0.086186
# 4                                     0.043146
# ..                                         ...
# 165                                   0.033086
# 166                                   0.073569
# 167                                   0.009852
# 168                                   0.018740
# 169                                   0.077137
#
#      ('aLvl_std', 'CRRA: 8.67, DiscFac: 0.97')  attention  ror_volatility  \
# 0                                     0.014591        0.0        0.009365
# 1                                     0.043865        0.0        0.015018
# 2                                     0.052474        0.0        0.009716
# 3                                     0.034936        0.0        0.013780
# 4                                     0.060178        0.0        0.007407
# ..                                         ...        ...             ...
# 165                                   0.036037        0.3        0.012083
# 166                                   0.113865        0.3        0.008694
# 167                                   0.024922        0.3        0.006343
# 168                                   0.010842        0.3        0.007303
# 169                                   2.946793        0.3        0.009353
#
#      dividend_ror  dividend_std  seconds att_cat   mock
# 0           0.001          0.01      613    0.0   False
# 1           0.001          0.01      531    0.0   False
# 2           0.001          0.01      531    0.0   False
# 3           0.001          0.01      574    0.0   False
# 4           0.001          0.01      567    0.0   False
# ..            ...           ...      ...     ...    ...
# 165         0.060          0.01      536    0.3   False
# 166         0.060          0.01      536    0.3   False
# 167         0.060          0.01      537    0.3   False
# 168         0.060          0.01      529    0.3   False
# 169         0.060          0.01      532    0.3   False
#
# [90 rows x 19 columns]

# %%
means = data.columns[:6]
stds = data.columns[6:12]

# %%
data[list(means) + ['attention']]
# Out:
#      ('aLvl_mean', 'CRRA: 3.33, DiscFac: 0.95')  \
# 0                                      0.377804
# 1                                      0.391418
# 2                                      0.156926
# 3                                      0.818857
# 4                                      0.251842
# ..                                          ...
# 165                                    0.306612
# 166                                    0.132826
# 167                                    0.204685
# 168                                    0.277392
# 169                                    0.793585
#
#      ('aLvl_mean', 'CRRA: 3.33, DiscFac: 0.97')  \
# 0                                      0.383700
# 1                                      0.419578
# 2                                      0.165370
# 3                                      0.369475
# 4                                      0.265152
# ..                                          ...
# 165                                    0.322638
# 166                                    0.132908
# 167                                    0.210390
# 168                                    0.298045
# 169                                    0.865397
#
#      ('aLvl_mean', 'CRRA: 6.0, DiscFac: 0.95')  \
# 0                                     0.849022
# 1                                     1.656456
# 2                                     0.974072
# 3                                     0.915677
# 4                                     0.756402
# ..                                         ...
# 165                                   0.701210
# 166                                   0.429886
# 167                                   0.558424
# 168                                   0.638733
# 169                                   1.478322
#
#      ('aLvl_mean', 'CRRA: 6.0, DiscFac: 0.97')  \
# 0                                     0.901912
# 1                                     1.181922
# 2                                     0.553890
# 3                                     0.943139
# 4                                     0.733352
# ..                                         ...
# 165                                   0.761912
# 166                                   0.464077
# 167                                   0.559453
# 168                                   0.633166
# 169                                   1.484355
#
#      ('aLvl_mean', 'CRRA: 8.67, DiscFac: 0.95')  \
# 0                                      1.166165
# 1                                      1.859732
# 2                                      0.758705
# 3                                      1.201748
# 4                                      1.034339
# ..                                          ...
# 165                                    1.037009
# 166                                    0.613283
# 167                                    0.772055
# 168                                    0.856155
# 169                                    1.934880
#
#      ('aLvl_mean', 'CRRA: 8.67, DiscFac: 0.97')  attention
# 0                                      1.159661        0.0
# 1                                      1.570719        0.0
# 2                                      0.750023        0.0
# 3                                      1.149143        0.0
# 4                                      1.026293        0.0
# ..                                          ...        ...
# 165                                    1.068629        0.3
# 166                                    0.599957        0.3
# 167                                    0.779638        0.3
# 168                                    0.877339        0.3
# 169                                    3.343068        0.3
#
# [90 rows x 7 columns]

# %%
mdata_mean = pd.melt(
    data[list(means) + ['attention']], 
    id_vars=['attention'], 
    value_vars=list(data.columns[:6]),
    var_name="stat"
)

mdata_std = pd.melt(
    data[list(stds) + ['attention']], 
    id_vars=['attention'], 
    value_vars=list(data.columns[6:12]),
    var_name="stat"
)

# %%
fig, ax = plt.subplots(figsize=(10,8))
sns.lineplot(
    ax=ax,
    data=mdata_mean,
    x="attention",
    y="value",
    hue="stat")
# Out:
# <AxesSubplot:xlabel='attention', ylabel='value'>

# %%
fig, ax = plt.subplots(figsize=(10,8))
sns.lineplot(
    ax=ax,
    data=mdata_std,
    x="attention",
    y="value",
    hue="stat")
# Out:
# <AxesSubplot:xlabel='attention', ylabel='value'>

# %%
fig, ax = plt.subplots(figsize=(10,8))
sns.lineplot(
    ax=ax,
    data=data,
    x="attention",
    y="ror_volatility")
# Out:
# <AxesSubplot:xlabel='attention', ylabel='ror_volatility'>

# %%
data['dstats'] = data['dividend_ror'].apply(lambda x : 'ror:' + str(x)) + data['dividend_std'].apply(lambda x : 'std:' + str(x))
# Out:
# <ipython-input-41-99b8925b092b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['dstats'] = data['dividend_ror'].apply(lambda x : 'ror:' + str(x)) + data['dividend_std'].apply(lambda x : 'std:' + str(x))

# %%
sns.lineplot(
    data = data,
    x = 'dividend_ror',
    y = 'ror_volatility',
    hue = 'dividend_std'
)
# Out:
# <AxesSubplot:xlabel='dividend_ror', ylabel='ror_volatility'>

# %%
sns.lineplot(
    data = data,
    x = 'dividend_std',
    y = 'ror_volatility',
    hue = 'dividend_ror'
)
# Out:
# <AxesSubplot:xlabel='dividend_std', ylabel='ror_volatility'>

# %%
data
# Out:
#      ('aLvl_mean', 'CRRA: 3.33, DiscFac: 0.95')  \
# 0                                      0.377804
# 1                                      0.391418
# 2                                      0.156926
# 3                                      0.818857
# 4                                      0.251842
# ..                                          ...
# 165                                    0.306612
# 166                                    0.132826
# 167                                    0.204685
# 168                                    0.277392
# 169                                    0.793585
#
#      ('aLvl_mean', 'CRRA: 3.33, DiscFac: 0.97')  \
# 0                                      0.383700
# 1                                      0.419578
# 2                                      0.165370
# 3                                      0.369475
# 4                                      0.265152
# ..                                          ...
# 165                                    0.322638
# 166                                    0.132908
# 167                                    0.210390
# 168                                    0.298045
# 169                                    0.865397
#
#      ('aLvl_mean', 'CRRA: 6.0, DiscFac: 0.95')  \
# 0                                     0.849022
# 1                                     1.656456
# 2                                     0.974072
# 3                                     0.915677
# 4                                     0.756402
# ..                                         ...
# 165                                   0.701210
# 166                                   0.429886
# 167                                   0.558424
# 168                                   0.638733
# 169                                   1.478322
#
#      ('aLvl_mean', 'CRRA: 6.0, DiscFac: 0.97')  \
# 0                                     0.901912
# 1                                     1.181922
# 2                                     0.553890
# 3                                     0.943139
# 4                                     0.733352
# ..                                         ...
# 165                                   0.761912
# 166                                   0.464077
# 167                                   0.559453
# 168                                   0.633166
# 169                                   1.484355
#
#      ('aLvl_mean', 'CRRA: 8.67, DiscFac: 0.95')  \
# 0                                      1.166165
# 1                                      1.859732
# 2                                      0.758705
# 3                                      1.201748
# 4                                      1.034339
# ..                                          ...
# 165                                    1.037009
# 166                                    0.613283
# 167                                    0.772055
# 168                                    0.856155
# 169                                    1.934880
#
#      ('aLvl_mean', 'CRRA: 8.67, DiscFac: 0.97')  \
# 0                                      1.159661
# 1                                      1.570719
# 2                                      0.750023
# 3                                      1.149143
# 4                                      1.026293
# ..                                          ...
# 165                                    1.068629
# 166                                    0.599957
# 167                                    0.779638
# 168                                    0.877339
# 169                                    3.343068
#
#      ('aLvl_std', 'CRRA: 3.33, DiscFac: 0.95')  \
# 0                                     0.040886
# 1                                     0.015979
# 2                                     0.008840
# 3                                     1.116104
# 4                                     0.000899
# ..                                         ...
# 165                                   0.050427
# 166                                   0.026487
# 167                                   0.014272
# 168                                   0.013994
# 169                                   0.120247
#
#      ('aLvl_std', 'CRRA: 3.33, DiscFac: 0.97')  \
# 0                                     0.016500
# 1                                     0.035096
# 2                                     0.012417
# 3                                     0.034826
# 4                                     0.003236
# ..                                         ...
# 165                                   0.028251
# 166                                   0.015341
# 167                                   0.007376
# 168                                   0.009071
# 169                                   0.073779
#
#      ('aLvl_std', 'CRRA: 6.0, DiscFac: 0.95')  \
# 0                                    0.029763
# 1                                    1.072083
# 2                                    1.038600
# 3                                    0.051191
# 4                                    0.037542
# ..                                        ...
# 165                                  0.015806
# 166                                  0.063858
# 167                                  0.002598
# 168                                  0.012003
# 169                                  0.093423
#
#      ('aLvl_std', 'CRRA: 6.0, DiscFac: 0.97')  \
# 0                                    0.048448
# 1                                    0.126739
# 2                                    0.039914
# 3                                    0.075061
# 4                                    0.036554
# ..                                        ...
# 165                                  0.022606
# 166                                  0.094828
# 167                                  0.004200
# 168                                  0.005585
# 169                                  0.127054
#
#      ('aLvl_std', 'CRRA: 8.67, DiscFac: 0.95')  \
# 0                                     0.052834
# 1                                     0.748476
# 2                                     0.048292
# 3                                     0.086186
# 4                                     0.043146
# ..                                         ...
# 165                                   0.033086
# 166                                   0.073569
# 167                                   0.009852
# 168                                   0.018740
# 169                                   0.077137
#
#      ('aLvl_std', 'CRRA: 8.67, DiscFac: 0.97')  attention  ror_volatility  \
# 0                                     0.014591        0.0        0.009365
# 1                                     0.043865        0.0        0.015018
# 2                                     0.052474        0.0        0.009716
# 3                                     0.034936        0.0        0.013780
# 4                                     0.060178        0.0        0.007407
# ..                                         ...        ...             ...
# 165                                   0.036037        0.3        0.012083
# 166                                   0.113865        0.3        0.008694
# 167                                   0.024922        0.3        0.006343
# 168                                   0.010842        0.3        0.007303
# 169                                   2.946793        0.3        0.009353
#
#      dividend_ror  dividend_std  seconds att_cat   mock             dstats
# 0           0.001          0.01      613    0.0   False  ror:0.001std:0.01
# 1           0.001          0.01      531    0.0   False  ror:0.001std:0.01
# 2           0.001          0.01      531    0.0   False  ror:0.001std:0.01
# 3           0.001          0.01      574    0.0   False  ror:0.001std:0.01
# 4           0.001          0.01      567    0.0   False  ror:0.001std:0.01
# ..            ...           ...      ...     ...    ...                ...
# 165         0.060          0.01      536    0.3   False   ror:0.06std:0.01
# 166         0.060          0.01      536    0.3   False   ror:0.06std:0.01
# 167         0.060          0.01      537    0.3   False   ror:0.06std:0.01
# 168         0.060          0.01      529    0.3   False   ror:0.06std:0.01
# 169         0.060          0.01      532    0.3   False   ror:0.06std:0.01
#
# [90 rows x 20 columns]
