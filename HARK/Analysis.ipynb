# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
import seaborn as sns

data = pd.read_csv("study-2021-Jun-1623428048_12:14).csv")
data = data.drop(columns="Unnamed: 0")

data["att_cat"] = data['attention'].apply(lambda x: str(x) + ' ')

sns.displot(
    data, 
    x="ror_volatility", 
    hue="attention", 
    element='step'
)

# %%
data
# Out:
#      ('aLvl_mean', 'CRRA: 3.33, DiscFac: 0.95')  \
# 0                                      0.930578
# 1                                      0.941829
# 2                                      1.060088
# 3                                      0.964341
# 4                                      0.953379
# ..                                          ...
# 699                                    0.696927
# 700                                    1.794670
# 701                                    0.624670
# 702                                    0.543810
# 703                                    0.554868
#
#      ('aLvl_mean', 'CRRA: 3.33, DiscFac: 0.97')  \
# 0                                      0.952125
# 1                                      1.015676
# 2                                      1.067865
# 3                                      0.993556
# 4                                      0.973131
# ..                                          ...
# 699                                    0.819984
# 700                                    2.054913
# 701                                    0.628043
# 702                                    0.557806
# 703                                    0.756766
#
#      ('aLvl_mean', 'CRRA: 6.0, DiscFac: 0.95')  \
# 0                                     1.271611
# 1                                     1.365473
# 2                                     1.469378
# 3                                     1.269798
# 4                                     1.110003
# ..                                         ...
# 699                                   0.963033
# 700                                   2.533187
# 701                                   0.746631
# 702                                   0.730038
# 703                                   0.709257
#
#      ('aLvl_mean', 'CRRA: 6.0, DiscFac: 0.97')  \
# 0                                     1.227263
# 1                                     1.372054
# 2                                     1.524429
# 3                                     1.127763
# 4                                     1.245179
# ..                                         ...
# 699                                   0.997011
# 700                                   2.404700
# 701                                   0.824403
# 702                                   0.739381
# 703                                   0.737728
#
#      ('aLvl_mean', 'CRRA: 8.67, DiscFac: 0.95')  \
# 0                                      1.407908
# 1                                      1.579130
# 2                                      1.761104
# 3                                      1.490992
# 4                                      1.442646
# ..                                          ...
# 699                                    1.042700
# 700                                    3.082658
# 701                                    0.926308
# 702                                    0.845386
# 703                                    0.867378
#
#      ('aLvl_mean', 'CRRA: 8.67, DiscFac: 0.97')  \
# 0                                      1.408057
# 1                                      1.549557
# 2                                      1.763948
# 3                                      1.500097
# 4                                      1.312631
# ..                                          ...
# 699                                    1.200529
# 700                                    2.878657
# 701                                    0.943805
# 702                                    0.859334
# 703                                    0.913369
#
#      ('aLvl_std', 'CRRA: 3.33, DiscFac: 0.95')  \
# 0                                     0.008008
# 1                                     0.168967
# 2                                     0.013909
# 3                                     0.009932
# 4                                     0.030419
# ..                                         ...
# 699                                   0.103396
# 700                                   0.058832
# 701                                   0.043332
# 702                                   0.012811
# 703                                   0.040317
#
#      ('aLvl_std', 'CRRA: 3.33, DiscFac: 0.97')  \
# 0                                     0.015708
# 1                                     0.016631
# 2                                     0.026821
# 3                                     0.013625
# 4                                     0.027338
# ..                                         ...
# 699                                   0.131472
# 700                                   0.639660
# 701                                   0.021614
# 702                                   0.023535
# 703                                   0.330394
#
#      ('aLvl_std', 'CRRA: 6.0, DiscFac: 0.95')  \
# 0                                    0.165427
# 1                                    0.041786
# 2                                    0.037348
# 3                                    0.017125
# 4                                    0.330618
# ..                                        ...
# 699                                  0.165534
# 700                                  0.354261
# 701                                  0.044139
# 702                                  0.028648
# 703                                  0.032816
#
#      ('aLvl_std', 'CRRA: 6.0, DiscFac: 0.97')  \
# 0                                    0.009981
# 1                                    0.041452
# 2                                    0.019099
# 3                                    0.417720
# 4                                    0.058799
# ..                                        ...
# 699                                  0.151447
# 700                                  0.346075
# 701                                  0.051241
# 702                                  0.031503
# 703                                  0.040267
#
#      ('aLvl_std', 'CRRA: 8.67, DiscFac: 0.95')  \
# 0                                     0.022390
# 1                                     0.045494
# 2                                     0.051009
# 3                                     0.059690
# 4                                     0.079977
# ..                                         ...
# 699                                   0.194656
# 700                                   0.435997
# 701                                   0.073340
# 702                                   0.017927
# 703                                   0.050701
#
#      ('aLvl_std', 'CRRA: 8.67, DiscFac: 0.97')  attention  ror_volatility  \
# 0                                     0.019870        0.0        0.011520
# 1                                     0.034299        0.0        0.011570
# 2                                     0.055931        0.0        0.011730
# 3                                     0.049399        0.0        0.013088
# 4                                     0.266692        0.0        0.012211
# ..                                         ...        ...             ...
# 699                                   0.200965        1.0        0.017273
# 700                                   0.297546        1.0        0.016257
# 701                                   0.090000        1.0        0.016092
# 702                                   0.020790        1.0        0.015610
# 703                                   0.058633        1.0        0.016744
#
#      dividend_ror  dividend_std att_cat
# 0           0.001          0.01    0.0
# 1           0.001          0.01    0.0
# 2           0.001          0.01    0.0
# 3           0.001          0.01    0.0
# 4           0.001          0.01    0.0
# ..            ...           ...     ...
# 699         0.100          0.01    1.0
# 700         0.100          0.01    1.0
# 701         0.100          0.01    1.0
# 702         0.100          0.01    1.0
# 703         0.100          0.01    1.0
#
# [704 rows x 17 columns]

# %%
means = data.columns[:6]
stds = data.columns[6:12]

# %%
data[list(means) + ['attention']]
# Out:
#      ('aLvl_mean', 'CRRA: 3.33, DiscFac: 0.95')  \
# 0                                      0.930578
# 1                                      0.941829
# 2                                      1.060088
# 3                                      0.964341
# 4                                      0.953379
# ..                                          ...
# 699                                    0.696927
# 700                                    1.794670
# 701                                    0.624670
# 702                                    0.543810
# 703                                    0.554868
#
#      ('aLvl_mean', 'CRRA: 3.33, DiscFac: 0.97')  \
# 0                                      0.952125
# 1                                      1.015676
# 2                                      1.067865
# 3                                      0.993556
# 4                                      0.973131
# ..                                          ...
# 699                                    0.819984
# 700                                    2.054913
# 701                                    0.628043
# 702                                    0.557806
# 703                                    0.756766
#
#      ('aLvl_mean', 'CRRA: 6.0, DiscFac: 0.95')  \
# 0                                     1.271611
# 1                                     1.365473
# 2                                     1.469378
# 3                                     1.269798
# 4                                     1.110003
# ..                                         ...
# 699                                   0.963033
# 700                                   2.533187
# 701                                   0.746631
# 702                                   0.730038
# 703                                   0.709257
#
#      ('aLvl_mean', 'CRRA: 6.0, DiscFac: 0.97')  \
# 0                                     1.227263
# 1                                     1.372054
# 2                                     1.524429
# 3                                     1.127763
# 4                                     1.245179
# ..                                         ...
# 699                                   0.997011
# 700                                   2.404700
# 701                                   0.824403
# 702                                   0.739381
# 703                                   0.737728
#
#      ('aLvl_mean', 'CRRA: 8.67, DiscFac: 0.95')  \
# 0                                      1.407908
# 1                                      1.579130
# 2                                      1.761104
# 3                                      1.490992
# 4                                      1.442646
# ..                                          ...
# 699                                    1.042700
# 700                                    3.082658
# 701                                    0.926308
# 702                                    0.845386
# 703                                    0.867378
#
#      ('aLvl_mean', 'CRRA: 8.67, DiscFac: 0.97')  attention
# 0                                      1.408057        0.0
# 1                                      1.549557        0.0
# 2                                      1.763948        0.0
# 3                                      1.500097        0.0
# 4                                      1.312631        0.0
# ..                                          ...        ...
# 699                                    1.200529        1.0
# 700                                    2.878657        1.0
# 701                                    0.943805        1.0
# 702                                    0.859334        1.0
# 703                                    0.913369        1.0
#
# [704 rows x 7 columns]

# %%
mdata_mean = pd.melt(
    data[list(means) + ['attention']], 
    id_vars=['attention'], 
    value_vars=list(data.columns[:6]),
    var_name="stat"
)

mdata_std = pd.melt(
    data[list(stds) + ['attention']], 
    id_vars=['attention'], 
    value_vars=list(data.columns[6:12]),
    var_name="stat"
)

# %%
fig, ax = plt.subplots(figsize=(10,8))
sns.lineplot(
    ax=ax,
    data=mdata_mean,
    x="attention",
    y="value",
    hue="stat")
# Out:
# <AxesSubplot:xlabel='attention', ylabel='value'>

# %%
fig, ax = plt.subplots(figsize=(10,8))
sns.lineplot(
    ax=ax,
    data=mdata_std,
    x="attention",
    y="value",
    hue="stat")
# Out:
# <AxesSubplot:xlabel='attention', ylabel='value'>

# %%
fig, ax = plt.subplots(figsize=(10,8))
sns.lineplot(
    ax=ax,
    data=data,
    x="attention",
    y="ror_volatility")
# Out:
# <AxesSubplot:xlabel='attention', ylabel='ror_volatility'>

# %%
data['dstats'] = data['dividend_ror'].apply(lambda x : 'ror:' + str(x)) + data['dividend_std'].apply(lambda x : 'std:' + str(x))

# %%
sns.lineplot(
    data = data,
    x = 'dividend_ror',
    y = 'ror_volatility',
    hue = 'dividend_std'
)
# Out:
# <AxesSubplot:xlabel='dividend_ror', ylabel='ror_volatility'>

# %%
sns.lineplot(
    data = data,
    x = 'dividend_std',
    y = 'ror_volatility',
    hue = 'dividend_ror'
)
# Out:
# <AxesSubplot:xlabel='dividend_std', ylabel='ror_volatility'>

# %%
data
# Out:
#      ('aLvl_mean', 'CRRA: 3.33, DiscFac: 0.95')  \
# 0                                      0.930578
# 1                                      0.941829
# 2                                      1.060088
# 3                                      0.964341
# 4                                      0.953379
# ..                                          ...
# 699                                    0.696927
# 700                                    1.794670
# 701                                    0.624670
# 702                                    0.543810
# 703                                    0.554868
#
#      ('aLvl_mean', 'CRRA: 3.33, DiscFac: 0.97')  \
# 0                                      0.952125
# 1                                      1.015676
# 2                                      1.067865
# 3                                      0.993556
# 4                                      0.973131
# ..                                          ...
# 699                                    0.819984
# 700                                    2.054913
# 701                                    0.628043
# 702                                    0.557806
# 703                                    0.756766
#
#      ('aLvl_mean', 'CRRA: 6.0, DiscFac: 0.95')  \
# 0                                     1.271611
# 1                                     1.365473
# 2                                     1.469378
# 3                                     1.269798
# 4                                     1.110003
# ..                                         ...
# 699                                   0.963033
# 700                                   2.533187
# 701                                   0.746631
# 702                                   0.730038
# 703                                   0.709257
#
#      ('aLvl_mean', 'CRRA: 6.0, DiscFac: 0.97')  \
# 0                                     1.227263
# 1                                     1.372054
# 2                                     1.524429
# 3                                     1.127763
# 4                                     1.245179
# ..                                         ...
# 699                                   0.997011
# 700                                   2.404700
# 701                                   0.824403
# 702                                   0.739381
# 703                                   0.737728
#
#      ('aLvl_mean', 'CRRA: 8.67, DiscFac: 0.95')  \
# 0                                      1.407908
# 1                                      1.579130
# 2                                      1.761104
# 3                                      1.490992
# 4                                      1.442646
# ..                                          ...
# 699                                    1.042700
# 700                                    3.082658
# 701                                    0.926308
# 702                                    0.845386
# 703                                    0.867378
#
#      ('aLvl_mean', 'CRRA: 8.67, DiscFac: 0.97')  \
# 0                                      1.408057
# 1                                      1.549557
# 2                                      1.763948
# 3                                      1.500097
# 4                                      1.312631
# ..                                          ...
# 699                                    1.200529
# 700                                    2.878657
# 701                                    0.943805
# 702                                    0.859334
# 703                                    0.913369
#
#      ('aLvl_std', 'CRRA: 3.33, DiscFac: 0.95')  \
# 0                                     0.008008
# 1                                     0.168967
# 2                                     0.013909
# 3                                     0.009932
# 4                                     0.030419
# ..                                         ...
# 699                                   0.103396
# 700                                   0.058832
# 701                                   0.043332
# 702                                   0.012811
# 703                                   0.040317
#
#      ('aLvl_std', 'CRRA: 3.33, DiscFac: 0.97')  \
# 0                                     0.015708
# 1                                     0.016631
# 2                                     0.026821
# 3                                     0.013625
# 4                                     0.027338
# ..                                         ...
# 699                                   0.131472
# 700                                   0.639660
# 701                                   0.021614
# 702                                   0.023535
# 703                                   0.330394
#
#      ('aLvl_std', 'CRRA: 6.0, DiscFac: 0.95')  \
# 0                                    0.165427
# 1                                    0.041786
# 2                                    0.037348
# 3                                    0.017125
# 4                                    0.330618
# ..                                        ...
# 699                                  0.165534
# 700                                  0.354261
# 701                                  0.044139
# 702                                  0.028648
# 703                                  0.032816
#
#      ('aLvl_std', 'CRRA: 6.0, DiscFac: 0.97')  \
# 0                                    0.009981
# 1                                    0.041452
# 2                                    0.019099
# 3                                    0.417720
# 4                                    0.058799
# ..                                        ...
# 699                                  0.151447
# 700                                  0.346075
# 701                                  0.051241
# 702                                  0.031503
# 703                                  0.040267
#
#      ('aLvl_std', 'CRRA: 8.67, DiscFac: 0.95')  \
# 0                                     0.022390
# 1                                     0.045494
# 2                                     0.051009
# 3                                     0.059690
# 4                                     0.079977
# ..                                         ...
# 699                                   0.194656
# 700                                   0.435997
# 701                                   0.073340
# 702                                   0.017927
# 703                                   0.050701
#
#      ('aLvl_std', 'CRRA: 8.67, DiscFac: 0.97')  attention  ror_volatility  \
# 0                                     0.019870        0.0        0.011520
# 1                                     0.034299        0.0        0.011570
# 2                                     0.055931        0.0        0.011730
# 3                                     0.049399        0.0        0.013088
# 4                                     0.266692        0.0        0.012211
# ..                                         ...        ...             ...
# 699                                   0.200965        1.0        0.017273
# 700                                   0.297546        1.0        0.016257
# 701                                   0.090000        1.0        0.016092
# 702                                   0.020790        1.0        0.015610
# 703                                   0.058633        1.0        0.016744
#
#      dividend_ror  dividend_std att_cat             dstats
# 0           0.001          0.01    0.0   ror:0.001std:0.01
# 1           0.001          0.01    0.0   ror:0.001std:0.01
# 2           0.001          0.01    0.0   ror:0.001std:0.01
# 3           0.001          0.01    0.0   ror:0.001std:0.01
# 4           0.001          0.01    0.0   ror:0.001std:0.01
# ..            ...           ...     ...                ...
# 699         0.100          0.01    1.0     ror:0.1std:0.01
# 700         0.100          0.01    1.0     ror:0.1std:0.01
# 701         0.100          0.01    1.0     ror:0.1std:0.01
# 702         0.100          0.01    1.0     ror:0.1std:0.01
# 703         0.100          0.01    1.0     ror:0.1std:0.01
#
# [704 rows x 18 columns]
